# %% [markdown]
# # In this project, you will learn practically how to choose the best features that help us to identify pulsar star using    Data analysis & data visualization  and then using these features in  logistic regression model   .
#
# We will go through 5 tasks to implement our project:
#
# Task 1: Importing libraries and Exploring the Dataset.
#
# Task 2: Checking missing values.
#
# Task 3: Creating visual methods to analyze the data.
#
# Task 4: make logistic regression model

# %% [markdown]
# # Task 1: Importing libraries and Exploring the Dataset.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
sns.set() #setting the default seaborn style for our plots

# %%
#importing the dataset
pulsar_df=pd.read_csv("pulsar_stars.csv")
#checking the head of the data
pulsar_df.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %%
#Info about the data shape of data, type of individual columns

pulsar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                17898 non-null  float64
#  1    Standard deviation of the integrated profile  17898 non-null  float64
#  2    Excess kurtosis of the integrated profile     17898 non-null  float64
#  3    Skewness of the integrated profile            17898 non-null  float64
#  4    Mean of the DM-SNR curve                      17898 non-null  float64
#  5    Standard deviation of the DM-SNR curve        17898 non-null  float64
#  6    Excess kurtosis of the DM-SNR curve           17898 non-null  float64
#  7    Skewness of the DM-SNR curve                  17898 non-null  float64
#  8   target_class                                   17898 non-null  int64
# dtypes: float64(8), int64(1)
# ...

# %% [markdown]
# Expected output:
#
#              1-The data should consist of 17898 data record with 9 attributes. 1 integer type, 8 float type .
#              2- no missing data.

# %% [markdown]
# #  Task 2: Checking missing values

# %%
# check the missing data after removing the all NAN.
pulsar_df.isna().apply(pd.value_counts)
# Out:
#         Mean of the integrated profile  \
# False                            17898
#
#         Standard deviation of the integrated profile  \
# False                                          17898
#
#         Excess kurtosis of the integrated profile  \
# False                                       17898
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# False                                17898                      17898
#
#         Standard deviation of the DM-SNR curve  \
# False                                    17898
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# False                                 17898                          17898
#
#        target_class
# False         17898

# %% [markdown]
# Expected output:
#                 No missing data

# %% [markdown]
# # Task 3: Creating visual methods to analyze the data.

# %%
# show the correlation in heatmap.
sns.heatmap(pulsar_df.corr(),cmap ='coolwarm',annot=True)

# %% [markdown]
# Expected output:(highly corrolated data is:)
#
#                 1-Excess kurtosis of the integrated profile.
#                 2-Skewness of the integrated profile .
#                 3-Skewness of the DM-SNR curve.
#                 4-Excess kurtosis of the DM-SNR curve.

# %%
#enhancing
pulsar_df['mean_profile']=pulsar_df.iloc[:,0]
pulsar_df['std_profile']=pulsar_df.iloc[:,1]
pulsar_df['Excess_kurtosis_profile']=pulsar_df.iloc[:,2]
pulsar_df['Skewness_profile']=pulsar_df.iloc[:,3]
pulsar_df['mean_DM_SNR']=pulsar_df.iloc[:,4]
pulsar_df['std_DM_SNR']=pulsar_df.iloc[:,5]
pulsar_df['Excess_kurtosis_DM_SNR']=pulsar_df.iloc[:,6]
pulsar_df['skewness_kurtosis_DM_SNR']=pulsar_df.iloc[:,6]
pulsar_df.head()
# Out:
#     Mean of the integrated profile  \
# 0                       140.562500
# 1                       102.507812
# 2                       103.015625
# 3                       136.750000
# 4                        88.726562
#
#     Standard deviation of the integrated profile  \
# 0                                      55.683782
# 1                                      58.882430
# 2                                      39.341649
# 3                                      57.178449
# 4                                      40.672225
#
#     Excess kurtosis of the integrated profile  \
# 0                                   -0.234571
# 1                                    0.465318
# 2                                    0.323328
# 3                                   -0.068415
# 4                                    0.600866
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.699648                   3.199833
# ...

# %%
pulsar1_df=pulsar_df.iloc[:,8:]
pulsar1_df.head()
# Out:
#    target_class  mean_profile  std_profile  Excess_kurtosis_profile  \
# 0             0    140.562500    55.683782                -0.234571
# 1             0    102.507812    58.882430                 0.465318
# 2             0    103.015625    39.341649                 0.323328
# 3             0    136.750000    57.178449                -0.068415
# 4             0     88.726562    40.672225                 0.600866
#
#    Skewness_profile  mean_DM_SNR  std_DM_SNR  Excess_kurtosis_DM_SNR  \
# 0         -0.699648     3.199833   19.110426                7.975532
# 1         -0.515088     1.677258   14.860146               10.576487
# 2          1.051164     3.121237   21.744669                7.735822
# 3         -0.636238     3.642977   20.959280                6.896499
# 4          1.123492     1.178930   11.468720               14.269573
#
#    skewness_kurtosis_DM_SNR
# 0                  7.975532
# 1                 10.576487
# 2                  7.735822
# ...

# %%
sns.pairplot(pulsar1_df)

# %%
sns.jointplot( x='Excess_kurtosis_profile',y='target_class',data=pulsar1_df,kind='scatter')

# %%
sns.jointplot( x='Skewness_profile',y='target_class',data=pulsar1_df,kind='scatter')

# %%
sns.jointplot( x='Skewness_profile',y='Excess_kurtosis_profile',data=pulsar1_df,kind='reg')

# %% [markdown]
# rom that we can deduce that:
#
#                          -Excess kurtosis of the integrated profile
#
#                          -Skewness of the integrated profile
# are the most important features

# %% [markdown]
# # Task 4: make logistic regression model

# %%
X=pulsar1_df.iloc[:,[3,4]].values
Y=pulsar1_df.iloc[:,[0]].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 41)

# %%
 #Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, Y_train)
# Out:
# C:\Users\Hashooma\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression(random_state=0)

# %%
# Predicting the Test set results
Y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_pred)
cm
# Out:
# array([[4060,   22],
#        [  82,  311]], dtype=int64)

# %%
from sklearn.metrics import classification_report                         # get  classification_report
cr=classification_report(Y_test, Y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4082
#            1       0.93      0.79      0.86       393
#
#     accuracy                           0.98      4475
#    macro avg       0.96      0.89      0.92      4475
# weighted avg       0.98      0.98      0.98      4475

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(Y_test, Y_pred)
print('accurcy of logistic model: ',acc *100,'%')
# Out:
# accurcy of logistic model:  97.67597765363128 %

# %% [markdown]
# from that we can deduce that:
#
#                              -Excess kurtosis of the integrated profile
#
#                              -Skewness of the integrated profile
# are the two important features that build the model  with accurcy 97.6%

# %% [markdown]
# # best wishes with accurcy 98%
